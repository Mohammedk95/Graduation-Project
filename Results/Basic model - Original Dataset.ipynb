# %% [markdown]
# (if you install the datasets it in google drive)

# %%
# Mount Google Drive to access the dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Import Required Libraries**
#
# This section imports all the necessary libraries for data processing, visualization, and building the CNN model.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import glob as gb
import cv2
import tensorflow as tf
import keras

# %% [markdown]
# **Define Dataset Path**
#
# Here, we define the path to the dataset. You can switch between different datasets by uncommenting the appropriate line.

# %%
# Define the path to the dataset
# First dataset
c = '/content/drive/MyDrive/Final Project/R_C_256/'

# Second dataset (commented out)
#c = '/content/drive/MyDrive/Final Project/Augmented18000/'

# Third dataset (commented out)
#c = '/content/drive/MyDrive/Final Project/Augmented data-set/'

# %% [markdown]
# **Map Class Names to Numerical Labels**
#
# This dictionary maps class names (Normal, Pothole, Cracks) to numerical labels (0, 1, 2).

# %%
# Define a dictionary to map class names to numerical labels
code = {'Normal':0 ,'Pothole':1,'Cracks':2}

# Function to get the class name from the numerical label
def getcode(n) :
    for x , y in code.items() :
        if n == y :
            return x

# %% [markdown]
# **Load Training Data**
#
# This section loads the training images and their corresponding labels into X_train and y_train.

# %%
# Load training data
X_train = []
y_train = []
for folder in  os.listdir(c +'Training') :
    files = gb.glob(pathname= str( c +'Training//' + folder + '/*.jpg'))
    for file in files:
        image = cv2.imread(file)
        X_train.append(list(image))
        y_train.append(code[folder])

# %% [markdown]
# **Load Testing Data**
#
# This section loads the testing images and their corresponding labels into X_test and y_test.

# %%
# Load testing data
X_test = []
y_test = []
for folder in  os.listdir(c +'Testing') :
    files = gb.glob(pathname= str(c + 'Testing//' + folder + '/*.jpg'))
    for file in files:
        image = cv2.imread(file)
        X_test.append(list(image))
        y_test.append(code[folder])

# %% [markdown]
# **Load Validation Data**
#
# This section loads the validation images and their corresponding labels into X_val and Y_val.

# %%
# Load validation data
X_val = []
Y_val = []
for folder in  os.listdir(c +'Validation') :
    files = gb.glob(pathname= str(c + 'Validation//' + folder + '/*.jpg'))
    for file in files:
        image = cv2.imread(file)
        X_val.append(list(image))
        Y_val.append(code[folder])

# %% [markdown]
# **Convert Lists to Numpy Arrays**
#
# Convert the lists of images and labels into numpy arrays for compatibility with TensorFlow/Keras.

# %%
# Convert lists to numpy arrays for compatibility with TensorFlow/Keras
X_train = np.array(X_train)
X_test = np.array(X_test)
X_val = np.array(X_val)
y_train = np.array(y_train)
y_test = np.array(y_test)
Y_val = np.array(Y_val)


print(f'X_train shape  is {X_train.shape}')
print(f'X_test shape  is {X_test.shape}')
print(f'X_val shape  is {X_val.shape}')
print(f'y_train shape  is {y_train.shape}')
print(f'y_test shape  is {y_test.shape}')
print(f'y_val shape  is {Y_val.shape}')
# Out:
# X_train shape  is (4445, 256, 256, 3)
# X_test shape  is (1110, 256, 256, 3)
# X_val shape  is (445, 256, 256, 3)
# y_train shape  is (4445,)
# y_test shape  is (1110,)
# y_val shape  is (445,)

# %% [markdown]
# **Define the CNN Model**
#
# This section defines the architecture of the Convolutional Neural Network (CNN) using Keras.

# %%
# Define the Convolutional Neural Network (CNN) model
KerasModel = keras.models.Sequential([
        keras.layers.Conv2D(16,kernel_size=(3,3),activation='relu',input_shape=(256,256,3)),
        keras.layers.MaxPool2D(2,2),
        keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(32,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(2,2),
        keras.layers.Conv2D(48,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(48,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(4,4),
        keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
        keras.layers.Conv2D(64,kernel_size=(3,3),activation='relu'),
        keras.layers.MaxPool2D(4,4),
        keras.layers.Flatten() ,
        keras.layers.Dense(120,activation='relu') ,
        keras.layers.Dense(90,activation='relu') ,
        keras.layers.Dense(60,activation='relu') ,
        keras.layers.Dense(30,activation='relu') ,
        keras.layers.Dense(3,activation='softmax') ,
        ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model with Adam optimizer and sparse categorical crossentropy loss
KerasModel.compile(optimizer ='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
# Print the model summary
print('Model Details are : ')
print(KerasModel.summary())
# Out:
# Model Details are :
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 254, 254, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 127, 127, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 125, 125, 32)        │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 123, 123, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 61, 61, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 59, 59, 48)          │          13,872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 57, 57, 48)          │          20,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 48)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 12, 12, 64)          │          27,712 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 10, 10, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 8, 8, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 120)                 │          30,840 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 90)                  │          10,890 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 60)                  │           5,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 30)                  │           1,830 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 3)                   │              93 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 199,673 (779.97 KB)
#  Trainable params: 199,673 (779.97 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# **Train the Model**
#
# This section trains the model using the training data and validates it using the validation data.

# %%
# Define early stopping callback to prevent overfitting
callback = keras.callbacks.EarlyStopping(monitor='accuracy', patience=3)

# %%
# Train the model
epochs = 50
ThisModel = KerasModel.fit(X_train, y_train, epochs=epochs,batch_size=32, validation_data = (X_val,Y_val), callbacks=[callback])
# Out:
# Epoch 1/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 24s 87ms/step - accuracy: 0.4385 - loss: 1.3004 - val_accuracy: 0.7843 - val_loss: 0.5701
# Epoch 2/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7176 - loss: 0.6560 - val_accuracy: 0.7348 - val_loss: 0.6505
# Epoch 3/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.7519 - loss: 0.5845 - val_accuracy: 0.8472 - val_loss: 0.3795
# Epoch 4/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8557 - loss: 0.3894 - val_accuracy: 0.8517 - val_loss: 0.3662
# Epoch 5/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8635 - loss: 0.3659 - val_accuracy: 0.8809 - val_loss: 0.3367
# Epoch 6/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8680 - loss: 0.3559 - val_accuracy: 0.8270 - val_loss: 0.4337
# Epoch 7/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8485 - loss: 0.3746 - val_accuracy: 0.8629 - val_loss: 0.3397
# Epoch 8/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9063 - loss: 0.2631 - val_accuracy: 0.9213 - val_loss: 0.2834
# Epoch 9/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8979 - loss: 0.2589 - val_accuracy: 0.9011 - val_loss: 0.2517
# Epoch 10/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9082 - loss: 0.2511 - val_accuracy: 0.8764 - val_loss: 0.3227
# Epoch 11/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9136 - loss: 0.2346 - val_accuracy: 0.9079 - val_loss: 0.2259
# Epoch 12/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9271 - loss: 0.1895 - val_accuracy: 0.9101 - val_loss: 0.2285
# Epoch 13/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9140 - loss: 0.2420 - val_accuracy: 0.9258 - val_loss: 0.2478
# Epoch 14/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9223 - loss: 0.2180 - val_accuracy: 0.9056 - val_loss: 0.3324
# Epoch 15/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9424 - loss: 0.1584 - val_accuracy: 0.8989 - val_loss: 0.2920
# Epoch 16/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9418 - loss: 0.1621 - val_accuracy: 0.9011 - val_loss: 0.2451
# Epoch 17/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9371 - loss: 0.1593 - val_accuracy: 0.8944 - val_loss: 0.3207
# Epoch 18/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9044 - loss: 0.2681 - val_accuracy: 0.9101 - val_loss: 0.3048
# Epoch 19/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9339 - loss: 0.1651 - val_accuracy: 0.9213 - val_loss: 0.2240
# Epoch 20/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9491 - loss: 0.1329 - val_accuracy: 0.9079 - val_loss: 0.3022
# Epoch 21/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9593 - loss: 0.1177 - val_accuracy: 0.8787 - val_loss: 0.3823
# Epoch 22/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9540 - loss: 0.1272 - val_accuracy: 0.9281 - val_loss: 0.3222
# Epoch 23/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9571 - loss: 0.1216 - val_accuracy: 0.9056 - val_loss: 0.3219
# Epoch 24/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9573 - loss: 0.1192 - val_accuracy: 0.9258 - val_loss: 0.2269
# Epoch 25/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9769 - loss: 0.0729 - val_accuracy: 0.9258 - val_loss: 0.3298
# Epoch 26/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9721 - loss: 0.0789 - val_accuracy: 0.9079 - val_loss: 0.3715
# Epoch 27/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9472 - loss: 0.1545 - val_accuracy: 0.9101 - val_loss: 0.2707
# Epoch 28/50
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9560 - loss: 0.1209 - val_accuracy: 0.9281 - val_loss: 0.2840

# %% [markdown]
# **Evaluate the Model**
#
# Evaluate the model's performance on the test dataset and print the accuracy and loss.

# %%
# Evaluate the model on the test dataset
loss,accuracy= KerasModel.evaluate(X_test, y_test)
print('Test accuracy: {:2.2f}%'.format(accuracy*100))
print('Test loss {:2.2f}%'.format(loss*100))
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step - accuracy: 0.9002 - loss: 0.4227
# Test accuracy: 94.95%
# Test loss 20.49%

# %%
ThisModel.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %% [markdown]
# **Plot Training and Validation Loss**
#
# Visualize the training and validation loss over epochs.

# %%
# Plot the training and validation loss
plt.style.use('bmh')
fig=plt.figure()
plt.plot(ThisModel.history['loss'],color='teal', label='loss')
plt.plot(ThisModel.history['val_loss'], color='orange', label='val_loss')
plt.title('MODEL LOSS')
plt.xlabel('EPOCHS')
plt.ylabel('LOSS')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Plot Training and Validation Accuracy**
#
# Visualize the training and validation accuracy over epochs.

# %%
# Plot the training and validation accuracy
plt.style.use('bmh')
fig=plt.figure()
plt.plot(ThisModel.history['accuracy'],color='teal', label='accuracy')
plt.plot(ThisModel.history['val_accuracy'], color='orange', label='val_accuracy')
plt.title('MODEL ACCURACY')
plt.xlabel('EPOCHS')
plt.ylabel('ACCURACY')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# **Confusion Matrix**
#
# This section computes and plots the confusion matrix to evaluate the model's performance.

# %%
# Function to plot the confusion matrix
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = KerasModel.predict(X_test)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred,axis = 1)


# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes)


# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(3))
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step

# %% [markdown]
# **Classification Report**
#
# Print the classification report to evaluate precision, recall, and F1-score.

# %%
# Print the classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, Y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97       370
#            1       0.94      0.95      0.94       370
#            2       0.95      0.91      0.93       370
#
#     accuracy                           0.95      1110
#    macro avg       0.95      0.95      0.95      1110
# weighted avg       0.95      0.95      0.95      1110

# %%
y_pred = KerasModel.predict(X_test)

print('Prediction Shape is {}'.format(y_pred.shape))
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Prediction Shape is (1110, 3)

# %%
y_result = KerasModel.predict(X_val)
print('Prediction Shape is {}'.format(y_result.shape))
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step
# Prediction Shape is (445, 3)

# %% [markdown]
# **Visualize Predictions**
#
# Visualize some random predictions from the validation dataset.

# %%
# Visualize some predictions
plt.figure(figsize=(20,20))
for n , i in enumerate(list(np.random.randint(0,len(X_val),36))) :
    plt.subplot(6,6,n+1)
    plt.imshow(X_val[i])
    plt.axis('off')
    plt.title(getcode(np.argmax(y_result[i])))

# %% [markdown]
# **The End**
